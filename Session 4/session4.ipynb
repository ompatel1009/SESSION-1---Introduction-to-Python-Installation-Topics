# %%
x = 'Flipkart-Sale2024'
result = x.lower().replace('-', ' ')
print(result)
# Out:
# flipkart sale2024

# %%
productname = ' OnePlus Nord-CE 3 '
result = productname.strip().upper().replace('-', ':')
print(result)
# Out:
# ONEPLUS NORD:CE 3

# %%
def split_product_code(product_code):
    return product_code.split('-')

result = split_product_code('ZOMATO-FOOD-2024')
print(result)
# Out:
# ['ZOMATO', 'FOOD', '2024']

# %%
x = 'Spotify_Premium_Offer'
result = x[8:15]
print(result)
# Out:
# Premium

# %%
product = 'Myntra Shirt'
price = 799.50

message = (f"Deal: {product} is available at ₹{price} only!")
print(message)
# Out:
# Deal: Myntra Shirt is available at ₹799.5 only!
